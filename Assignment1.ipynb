# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snb

# %%
# data= pd.read_csv("./Data/iris_dataset/iris.data.csv")
data= pd.read_csv("./Data/iris_dataset/iris.dataCopy.csv")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Declaration 
# sepal_length= data["5.1"]
# sepal_width= data["3.5"]
# petal_length= data["1.4"]
# petal_width= data["0.2"]

# %% [markdown]
# 1. Visualizing Distributions

# %%
#  creating a histogram for visualisation of measurement of the various samples 
# plt.hist([sepal_length,sepal_width,petal_length,petal_width])

# Histogram for Sepal_length
plt.hist(data.sepal_length)
plt.title("Histogram for sepal_length")
plt.show()

# %%
# Histogram for sepal_width
plt.hist(data.sepal_width)
plt.title("Histogram for sepal_width")
plt.show()

# %%
# Histogram for petal_length
plt.hist(data.petal_length)
plt.title("Histogram for petal_length")
plt.show()

# %%
# Histogram for petal_width
plt.hist(data.petal_width)
plt.title("Histogram for petal_width")
plt.show()

# %%
# Box plot for comparism btween  the different samples
    # Using Seaborn
    # Box-Plot for sepal_length and petal_length
snb.boxplot( data=data, x="sepal_length", y="petal_width", hue="species" )
plt.title("Box-Plot for sepal_length and petal_width")
plt.show()

# %%
# Box-Plot for sepal_width and petal_length
snb.boxplot( data=data, x="sepal_width", y= "petal_length", hue="species")
plt.title("Box-Plot for sepal_length and petal_length")
plt.show()

# %% [markdown]
# 2. Exploring Relationships

# %%
snb.scatterplot(data=data, x="sepal_length", y="sepal_width" , hue="species" )
plt.title("A Scattered diagram of the sepal_length and sepal_width ")
plt.show()

# %%
snb.scatterplot(data=data, x="petal_length", y="petal_width", hue="species")
plt.title("A Scattered diagram of the petal_length and petal_width ")
plt.show()

# %%
snb.heatmap(data.corr(), annot=True )
plt.title("A Correlation of the Species")
plt.show()

# %% [markdown]
# 3. Analyzing Categorical Features

# %%
# Using Bar-chart 
plt.bar(x="species",height=50, data=data)
plt.title("Barchart for the species")
plt.show()

# %%
plt.pie(x=data["species"].value_counts(),labels=data["species"].unique(), radius=2,shadow=True)
plt.title("Piechart for the Species")
plt.show()

# %% [markdown]
# 4. Enhancing Visualizations

# %%
# 4. Enchancing visualisation
plt.hist([sepal_length,sepal_width,petal_length,petal_width],label=["sepal_length", "sepal_width", "petal_length","petal_width"])

#  Adding Title
plt.title("Flower sampling")

# Adding axes labels
plt.xlabel("Measurement values ")
plt.ylabel("Number of Flowers ")
# Legend
plt.legend()

# %%
# Adding MARKER and 
snb.scatterplot(data=data, x="petal_length", y="petal_width", hue="species", marker= "+")
plt.title("A Scattered diagram of the petal_length and petal_width ")
plt.show()
